# %%
# !pip install pandas openpyxl

import pandas as pd
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
dfGOV = pd.read_csv("https://raw.githubusercontent.com/DerikVoid/Projeto-metadado_Gov/refs/heads/main/comprasGOV-diario-VW_FT_PNCP_COMPRA_ITEM-latest.csv")
dfGOV.head(5)
# Out:
#    srk_pncp_item_compra  cod_compra  cod_item_compra  codigo_classe  \
# 0              49189670    10454508         52023071            NaN
# 1              49211717    10492305         52357922            NaN
# 2              49211718    10492305         52357923            NaN
# 3              49211719    10492466         52358579            NaN
# 4              49211720    10486291         52318432            NaN
#
#    codigo_grupo  numero_item_pncp  numero_grupo  numero_item_compra  \
# 0           NaN                 1             0                   1
# 1           NaN                 2             0                   2
# 2           NaN                 3             0                   3
# 3           NaN                 1             0                   1
# 4           NaN                 1             0                   1
#
#   descricao_detalhada                                 descricao_resumida  ...  \
# 0                 NaN  Prestação de Serviços de Eletricista Prestação...  ...
# 1                 NaN  Publicação Legal / Editais Publicação Legal / ...  ...
# 2                 NaN  Publicação Legal / Editais Publicação Legal / ...  ...
# 3                 NaN  Desinsetização / Desratização / Dedetização De...  ...
# 4                 NaN  Manutenção Extintores / Mangueiras - Combate I...  ...
#
#   percentual_margem_preferencia_normal margem_preferencia_adicional  \
# 0                                  NaN                        False
# 1                                  NaN                        False
# 2                                  NaN                        False
# 3                                  NaN                        False
# 4                                  NaN                        False
#
#    percentual_margem_preferencia_adicional  codigo_NCM  descricao_NCM  \
# 0                                      NaN         NaN            NaN
# 1                                      NaN         NaN            NaN
# 2                                      NaN         NaN            NaN
# 3                                      NaN         NaN            NaN
# 4                                      NaN         NaN            NaN
#
#     numero_controle_PNCP_compra  TXT_LINK_MATERIAL  TXT_LINK_CLASSE  \
# 0  00394502000144-1-003026/2026                NaN              NaN
# 1  96291141000180-1-002211/2026                NaN              NaN
# 2  96291141000180-1-002211/2026                NaN              NaN
# 3  96291141000180-1-002212/2026                NaN              NaN
# 4  96291141000180-1-002194/2026                NaN              NaN
#
#   TXT_LINK_SERVICO  TXT_LINK_GRUPO
# 0              NaN             NaN
# 1              NaN             NaN
# 2              NaN             NaN
# 3              NaN             NaN
# 4              NaN             NaN
#
# [5 rows x 56 columns]

# %%
#Filtra todas as colunas que não possuem valores algum dentro delas
dados_limps = dfGOV.iloc[:, 0: 136].dropna(how='all', axis=1)
dfGOV.update(dados_limps)
print(dfGOV)
# Out:
#      srk_pncp_item_compra  cod_compra  cod_item_compra  codigo_classe  \
# 0                49189670    10454508         52023071            NaN
# 1                49211717    10492305         52357922            NaN
# 2                49211718    10492305         52357923            NaN
# 3                49211719    10492466         52358579            NaN
# 4                49211720    10486291         52318432            NaN
# ..                    ...         ...              ...            ...
# 129              49219611    10493102         52360797            NaN
# 130              49219612    10492500         52358988            NaN
# 131              49219613    10492371         52358360            NaN
# 132              49219614    10492393         52358423            NaN
# 133              49219615    10442592         51885698            NaN
#
#      codigo_grupo  numero_item_pncp  numero_grupo  numero_item_compra  \
# 0             NaN                 1             0                   1
# 1             NaN                 2             0                   2
# 2             NaN                 3             0                   3
# 3             NaN                 1             0                   1
# 4             NaN                 1             0                   1
# ..            ...               ...           ...                 ...
# 129           NaN                 1             0                   1
# 130           NaN                 1             0                   1
# 131           NaN                 1             0                   1
# 132           NaN                 1             0                   1
# 133           NaN                 1             0                   1
#
#     descricao_detalhada                                 descricao_resumida  \
# 0                   NaN  Prestação de Serviços de Eletricista Prestação...
# 1                   NaN  Publicação Legal / Editais Publicação Legal / ...
# 2                   NaN  Publicação Legal / Editais Publicação Legal / ...
# 3                   NaN  Desinsetização / Desratização / Dedetização De...
# 4                   NaN  Manutenção Extintores / Mangueiras - Combate I...
# ..                  ...                                                ...
# 129                 NaN          Seminário / palestra Seminário / palestra
# 130                 NaN          Seminário / Palestra Seminário / Palestra
# 131                 NaN  Treinamento na Área de Administração Pública V...
# 132                 NaN  Treinamento na Área de Administração Pública V...
# 133                 NaN  Indicador Biológico tipo: terceira geração, ap...
#
#      ... percentual_margem_preferencia_normal margem_preferencia_adicional  \
# 0    ...                                  NaN                        False
# 1    ...                                  NaN                        False
# 2    ...                                  NaN                        False
# 3    ...                                  NaN                        False
# 4    ...                                  NaN                        False
# ..   ...                                  ...                          ...
# 129  ...                                  NaN                        False
# 130  ...                                  NaN                        False
# 131  ...                                  NaN                        False
# 132  ...                                  NaN                        False
# 133  ...                                  NaN                        False
#
#      percentual_margem_preferencia_adicional  codigo_NCM  descricao_NCM  \
# 0                                        NaN         NaN            NaN
# 1                                        NaN         NaN            NaN
# 2                                        NaN         NaN            NaN
# 3                                        NaN         NaN            NaN
# 4                                        NaN         NaN            NaN
# ..                                       ...         ...            ...
# 129                                      NaN         NaN            NaN
# 130                                      NaN         NaN            NaN
# 131                                      NaN         NaN            NaN
# 132                                      NaN         NaN            NaN
# 133                                      NaN         NaN            NaN
#
#       numero_controle_PNCP_compra  TXT_LINK_MATERIAL  TXT_LINK_CLASSE  \
# 0    00394502000144-1-003026/2026                NaN              NaN
# 1    96291141000180-1-002211/2026                NaN              NaN
# 2    96291141000180-1-002211/2026                NaN              NaN
# 3    96291141000180-1-002212/2026                NaN              NaN
# 4    96291141000180-1-002194/2026                NaN              NaN
# ..                            ...                ...              ...
# 129  00509968000148-1-001151/2026                NaN              NaN
# 130  00509968000148-1-001147/2026                NaN              NaN
# 131  00627612000109-1-000057/2026                NaN              NaN
# 132  00627612000109-1-000058/2026                NaN              NaN
# 133  17879859000115-1-000031/2026                NaN              NaN
#
#     TXT_LINK_SERVICO  TXT_LINK_GRUPO
# 0                NaN             NaN
# 1                NaN             NaN
# 2                NaN             NaN
# 3                NaN             NaN
# 4                NaN             NaN
# ..               ...             ...
# 129              NaN             NaN
# 130              NaN             NaN
# 131              NaN             NaN
# 132              NaN             NaN
# 133              NaN             NaN
#
# [134 rows x 56 columns]
